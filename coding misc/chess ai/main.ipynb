# %%
import chess

board = chess.Board()
board
# Out:
# Board('rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1')

# %% [markdown]
# **Chess**

# %%
board = chess.Board("r1bqkb1r/pp1n1ppp/2p1pn2/3p4/2PP4/2N2NP1/PP2PPBP/R1BQK2R w KQkq - 0 6")
board
# Out:
# Board('r1bqkb1r/pp1n1ppp/2p1pn2/3p4/2PP4/2N2NP1/PP2PPBP/R1BQK2R w KQkq - 0 6')

# %%
import chess.engine

# engine_path = "/Users/jasperchong/opt/miniconda3/lib/python3.9/site-packages/chess/engine.py"
# engine = chess.engine.SimpleEngine.popen_uci(engine_path)
engine = chess.engine.SimpleEngine.popen_uci('~/Stockfish-sf_15.1')

fen = "r1bqkb1r/pp1n1ppp/2p1pn2/3p4/2PP4/2N2NP1/PP2PPBP/R1BQK2R w KQkq - 0 6"
board = chess.Board(fen)

# analyze the position for 5 seconds
info = engine.analyse(board, chess.engine.Limit(time=5.0))

print("Score:", info["score"])
board
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/jasperchong/Desktop/chess ai/main.ipynb Cell 5 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/jasperchong/Desktop/chess%20ai/main.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> import chess.engine
#       <a href='vscode-notebook-cell:/Users/jasperchong/Desktop/chess%20ai/main.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> # engine_path = "/Users/jasperchong/opt/miniconda3/lib/python3.9/site-packages/chess/engine.py"
#       <a href='vscode-notebook-cell:/Users/jasperchong/Desktop/chess%20ai/main.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> # engine = chess.engine.SimpleEngine.popen_uci(engine_path)
# ----> <a href='vscode-notebook-cell:/Users/jasperchong/Desktop/chess%20ai/main.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> engine = chess.engine.SimpleEngine.popen_uci('~/Stockfish-sf_15.1')
# ...
