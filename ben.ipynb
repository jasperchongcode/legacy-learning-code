# %%
import numpy as np
import matplotlib.pyplot as plt
from argand import argand
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/jasperchong/PycharmProjects/ben.ipynb Cell 1 line <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/jasperchong/PycharmProjects/ben.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
#       <a href='vscode-notebook-cell:/Users/jasperchong/PycharmProjects/ben.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell:/Users/jasperchong/PycharmProjects/ben.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from argand import argand
#
# ModuleNotFoundError: No module named 'argand'

# %%
def z(theta):
 return np.e**(theta*1.j)+np.e**(np.pi*theta*1.j)

# %%
x = [i for i in range(0,99999,1)]

# %%
a = np.vectorize(z)(x)

# %%
fig, ax = plt.subplots()
ax.scatter(a.real, a.imag)

fig.show()
# Out:
# /var/folders/f5/9kn8mtyn7p1cdn40mw2mhtn80000gn/T/ipykernel_16216/3433195693.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Out:
# array([ 2.        +0.j        , -0.45969769+0.84147098j,
#         0.58385316+0.90929743j, ...,  1.62617104-0.77968573j,
#        -0.00559543+0.10563876j,  1.44838713+0.89383946j])

# %%
from cmath import pi, e, polar
from numpy import linspace, vectorize, sin, cos
from numpy.random import rand
from matplotlib import pyplot as plt

# Arrays of evenly spaced angles, and random lengths
angles = linspace(0, 2*pi, 1000, endpoint=False)
lengths = 3*rand(*angles.shape)

# Create an array of complex numbers in Cartesian form
z = lengths * (e ** (1j*angles)+e ** (1j*angles*pi))

# np.e**(theta*1.j)+np.e**(np.pi*theta*1.j)

# Convert back to polar form
vect_polar = vectorize(polar)
rho_theta = vect_polar(z)

# Plot numbers on polar projection
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.stem(rho_theta[1], rho_theta[0])

# Get a number, find projections on axes
n = 11
rho, theta = rho_theta[0][n], rho_theta[1][n]
a = cos(theta)
b = sin(theta)
rho_h, theta_h = abs(a)*rho, 0 if a >= 0 else -pi
rho_v, theta_v = abs(b)*rho, pi/2 if b >= 0 else -pi/2

# # Plot h/v lines on polar projection
# ax.plot((theta_h, theta), (rho_h, rho), c='r', ls='--')
# ax.plot((theta, theta_v), (rho, rho_v), c='g', ls='--')
